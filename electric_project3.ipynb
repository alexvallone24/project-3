# %%
pip install pymongo

# %%
# Module used to connect Python with MongoDB
from pymongo import MongoClient

# %%
# The default port used by MongoDB is 27017
# https://docs.mongodb.com/manual/reference/default-mongodb-port/
mongo = MongoClient(port=27017)

# Define the 'classDB' database in Mongo
db = mongo.classDB

# Declare the collection
classroom = db.classroom

# %%
# Insert a document into the 'classroom' collection
classroom.insert_one(
    {
        'name': 'Ahmed',
        'row': 3,
        'favorite_python_library': 'Matplotlib',
        'hobbies': ['Running', 'Stargazing', 'Reading']
    }
)

# Query the classroom collection.
students = classroom.find()

# See the data in collection
for student in students:
    print(student)
# Out:
# {'_id': ObjectId('67ad4d8133994c2602ca3d13'), 'name': 'Delaram Dadfarnia', 'favorite_python_library': 'Excel', 'age': 46, 'Hobbies': ['Painting']}
# {'_id': ObjectId('67ad4e6933994c2602ca3d14'), 'name': 'bob', 'favorite_python_library': 'panda', 'age': 30, 'Hobbies': ['cooking']}
# {'_id': ObjectId('67ba2b79e51c5a58df318806'), 'name': 'Ahmed', 'row': 3, 'favorite_python_library': 'Matplotlib', 'hobbies': ['Running', 'Stargazing', 'Reading']}

# %%
# Update a document
classroom.update_one(
    {'name': 'Ahmed'},
    {'$set':
        {'row': 4}
     }
)

# Query the classroom collection
students = classroom.find()

# See the change in collection.
for student in students:
    print(student)
# Out:
# {'_id': ObjectId('67ad4fac6cb3f92e56e74f6c'), 'name': 'Dinnara', 'age': 'younger than me', 'favorite_python_library': 'Pandas', 'hobbies': ['Her kids (even though they are old)', 'python', 'pilates']}
# {'_id': ObjectId('67ae900b4957c53dcef9c98c'), 'name': 'Ahmed', 'row': 4, 'favorite_python_library': 'Matplotlib', 'hobbies': ['Running', 'Stargazing', 'Reading']}

# %%
# Add an item to a document array
classroom.update_one(
    {'name': 'Ahmed'},
    {'$push':
        {'hobbies': 'Listening to country music'}
    }
)

# Query the classroom collection.
students = classroom.find()

# See the change in collection.
for student in students:
    print(student)
# Out:
# {'_id': ObjectId('67ad4fac6cb3f92e56e74f6c'), 'name': 'Dinnara', 'age': 'younger than me', 'favorite_python_library': 'Pandas', 'hobbies': ['Her kids (even though they are old)', 'python', 'pilates']}
# {'_id': ObjectId('67ae900b4957c53dcef9c98c'), 'name': 'Ahmed', 'row': 4, 'favorite_python_library': 'Matplotlib', 'hobbies': ['Running', 'Stargazing', 'Reading', 'Listening to country music']}

# %%
# Delete a field from a document
classroom.update_one({'name': 'Ahmed'},
     {'$unset':
          {'row': ""}
     }
)

# Query the classroom collection
students = classroom.find()

# See the change in collection.
for student in students:
    print(student)
# Out:
# {'_id': ObjectId('67ad4fac6cb3f92e56e74f6c'), 'name': 'Dinnara', 'age': 'younger than me', 'favorite_python_library': 'Pandas', 'hobbies': ['Her kids (even though they are old)', 'python', 'pilates']}
# {'_id': ObjectId('67ae900b4957c53dcef9c98c'), 'name': 'Ahmed', 'favorite_python_library': 'Matplotlib', 'hobbies': ['Running', 'Stargazing', 'Reading', 'Listening to country music']}

# %%
# Delete a document from a collection
classroom.delete_one(
    {'name': 'Ahmed'}
)

# Query the classroom collection
students = db.classroom.find()

# See the change in collection.
for student in students:
    print(student)
# Out:
# {'_id': ObjectId('67ad4fac6cb3f92e56e74f6c'), 'name': 'Dinnara', 'age': 'younger than me', 'favorite_python_library': 'Pandas', 'hobbies': ['Her kids (even though they are old)', 'python', 'pilates']}
